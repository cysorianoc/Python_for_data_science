# %% [markdown]
# <a href="https://colab.research.google.com/github/cysorianoc/Python_for_data_science/blob/main/Python_Fund_W1_UCB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python Fundamentals
# Week 1 notes
#
# Module 1: introduction to Python
#
# What are computers ?
# - Computers compute data according to **instructions**;
# - Components: CPU, memory, storage, input/output devices.
#
# Instructions
# - Computers can only understand binary.
# - We cannot us machine language directly.
# - To communicate we use high level languages as Python. So they convert to machine language.
# - Programming Languages: connect computers and humans. Here we have grammatical rules to provide instructions to a computer.
#
# Python
# - High level and general purpose programming language.
# - Advantages: small code length, user-friendly, extensive libraries. Excellent for Data Science.
# - Python 3 is the current standard (2024).

# %% [markdown]
# Module 1: Python Environment
# - We can use an online environment to avoid installations and configurations: Google Colab.
#     - Zero configuration required.
#     - Easy sharing
# - Install a local IDE (Integrated Development Environment): Anaconda.
#     - Run JupyterLab or Jupyter Notebook to create interactive Python scripts.

# %% [markdown]
# Now, let's see somme examples on google Colab:

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print('Hello, Di!')
# Out:
# Hello, Di!

# %% [markdown]
# - ``print`` is a keyword predefined for output.
# - ``()`` indicates that you are going to call the function.
# - `Hello, world!` is the message you want to print.
# - `''` the quotations are necessary to print our message (this will be explained after).

# %% [markdown]
# Module 1: Quotations
# - `''` quotations wrap the message.
# - `''` or `""` they can be single or double: preferred single quotations.
# - Triple quotations are used for commentaries and documentation. They can have multiple lines.
#
# Let's see more examples:

# %%
# Here we use a scape mark, a backshlash \ before 'm.
# The backshlash says that this not makes part of the syntax
print('I\'m OK')
# Out:
# I'm OK

# %%
print("I'm OK")
# Out:
# I'm OK

# %%
# Insert a new line with \n
print('This is a new \n line')
# Out:
# This is a new
#  line

# %%
print('''
This
is
the
first
line''')
# Out:
# This
# is
# the
# first
# line

# %% [markdown]
# # Welcome to our first Lab Practice!

# %% [markdown]
# This lab is all about print() and we are going to print various messages on the screen. Are you ready? Let's get started!

# %% [markdown]
# You will find some small tasks in sections below. You should use print() and a proper choice of quotation marks to print the **message** on the screen.

# %% [markdown]
# ## Single quotations ' '

# %% [markdown]
# ###Task: print message **Hello, world!**

# %%
# type your code here
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ###Task: print message **"Hello, world!"**
#
# Note: the **" "** is part of the message and it should be included in the message printed out.

# %%
# your code will be here
print('"Hello, world!"')
# Out:
# "Hello, world!"

# %% [markdown]
# ###Task: print message **"How are you?"**
#
# Note: the **" "** is part of the message and it should be included in the message printed out.

# %%
# your code will be here
print('"How are you?"')
# Out:
# "How are you?"

# %% [markdown]
# ## Double quotations " "

# %% [markdown]
# ###Task: print message **Hello, world!** (using " ")

# %%
# your code will be here
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ###Task: print message **I'm fine.**

# %%
# your code will be here
print("I'm fine.")
# Out:
# I'm fine.

# %% [markdown]
# ###Task: print message **It's a great day!**

# %%
# your code will be here
print("It's a great day!")
# Out:
# It's a great day!

# %% [markdown]
# ## Triple quotations ''' '''

# %% [markdown]
# ###Task: print the poem below
#
# **This**
#
# **is**
#
# **a**
#
# **poem**

# %%
# your code will be here
print('''
This
is
a
poem
''')
# Out:
# This
# is
# a
# poem

# %% [markdown]
# ###Task: print the paragraph below
#
# **This is a multi-line**
#
# **documentary. It consists**
#
# **several sentences and**
#
# **might be pages long.**

# %%
# your code will be here
print('''
This is a multi-line\n
documentary. It consists\n
several sentences and\n
might be pages long.
''')
# Out:
#
# This is a multi-line
#
# documentary. It consists
#
# several sentences and
#
# might be pages long.

# %% [markdown]
# ## Combinations of quotations

# %% [markdown]
# ###Task: print the dialog below
#
# **"How are you?"**
#
# **"I'm fine."**
#
# **"It's a great day!"**

# %%
# your code will be here
print('''
"How are you?"

"I'm fine."

"It's a great day!"
''')
# Out:
# "How are you?"
#
# "I'm fine."
#
# "It's a great day!"

# %% [markdown]
# # Week 1 Part 2: Python input()
#
# - Inside ``print()``, we have an ``input()`` function.
# - () indicated that we call the function.
# - The name you typed will be taken into account in a future calculation.
# - We can combine inputs and outputs.

# %%
print(input('What is tour name? '))
# Out:
# What is tour name?Cristian
# Cristian

# %%
print('Hello,',input('What is your name? '))
# Out:
# What is your name? Cristian
# Hello, Cristian

# %% [markdown]
# - you can have multiple messages in ``print()``
# - Each message will be separated by a comma (,)

# %% [markdown]
# # Lab practice
#
# This lab is all about input() and we are going to get all kinds of information from the user (you) and print the respnose on the screen: Are you ready? Let's get started!
# You will find some small tasks in sections below: You should use input() to get the user to enter the information and use print() to print the information on the screen:

# %% [markdown]
# ## Ask for names
#
# ###Task: Ask **"What's your name?"** and print the input on the screen

# %%
print(input('What is tour name? '))
# Out:
# What is tour name? Cristian
# Cristian

# %% [markdown]
# ###Task: Ask **"How do you feel so far? Enter 1; for Good; 2 for very good"** and print the input on the screen

# %%
print(input('How do you feel so far? Enter 1; for Good; 2 for very good'))
# Out:
# How do you feel so far? Enter 1; for Good; 2 for very good2
# 2

# %% [markdown]
# ###Task: Ask **"Are you ready to learn more? Enter Yes or No"** and print the input on the screen.

# %%
print(input('Are you ready to learn more? Enter Yes or No'))
# Out:
# Are you ready to learn more? Enter Yes or NoYes
# Yes

# %% [markdown]
# ## Week 1 Quiz

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Welcome to our first assignment!
# This assignment is about testing your understanding of print() and input(). We are going to create some interactive programs using these two simple tools. Are you ready? Let's get started!
#
# You will find some small tasks in sections below. You should use input() to get the user to enter the information and use print() to print the information on the screen.
#
# Prepare a document
# Instruction: You are going to print a document on the screen. The document is a template, which has {} as place holder and should get inputs from the user. Let's get it done step by step.
# You should use multiple input() to get the information from the user.
#
# The template is as below:
#
# Dear {receiver's name}:
#
# This is {your first name}. I'm writing to let you know that the weather in {your location} is fantastic!
#
# I'm taking Python for Data Science course. I have coded {#} programs and the expereince was fun! Join me if you are interested!
#
# Sincerely,
#
# {your full name}
#
# {date}

# %% [markdown]
# Step1: Get receiver's name, and print line 1:
#
# Dear {receiver's name}:

# %%
print('Dear', input('{receiver\'s name}'),':')

# %% [markdown]
# Step2: Get your first name, your location and print line 2:
#
# This is {your first name}. I'm writing to let you know that the weather in {your location} is fantastic!

# %%
print('This is', input('{your first name}'),'I\'m writing to let you know that the weather in', input('{your location}'), 'is fantastic.')

# %% [markdown]
# Step3: Get the number of programs you have practiced, and print line 3:
#
# I'm taking Python for Data Science course. I have coded {# of programs} programs and the expereince was fun! Join me if you are interested!

# %%
print('I\'m taking Python for Data Science course, I have coded', input('{# of programs}'),'and the experience was fun!. Join me if you are interested.')

# %% [markdown]
# Step 4: print line 4:
#
# Sincerely,

# %%
print('Sincerely,')

# %% [markdown]
# Step 5: Get your full name and print line 5:
#
# {your full name}

# %%
print(input('Enter your full name:'))

# %% [markdown]
# Step 6: Get today's date and print line 6:
#
# {date}

# %%
print(input('Enter today\'s date'))
